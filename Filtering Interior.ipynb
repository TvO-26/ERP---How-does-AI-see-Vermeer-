# %%
#mount to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read csv from drive path
import pandas as pd
path = '/content/drive/MyDrive/ERP Rijksmuseum /rijks_17th_paintings_metadata_raw.csv'
dataunfiltered = pd.read_csv(path)

# %%
dataunfiltered.head()
# Out:
#                                     id objectNumber  \
# 0  https://id.rijksmuseum.nl/200107757    SK-A-4013
# 1  https://id.rijksmuseum.nl/200107770     SK-A-276
# 2  https://id.rijksmuseum.nl/200107771    SK-C-1440
# 3  https://id.rijksmuseum.nl/200107776    SK-C-1215
# 4  https://id.rijksmuseum.nl/200107777    SK-A-4232
#
#                                             title_en  \
# 0  Portrait of Govert van Slingelandt (1623-1690)...
# 1      Een herderin, bekend als 'De schone herderin'
# 2  Portrait of a Man, possibly Reijnier Pauw (159...
# 3  Portrait of Thomas Hees (b. 1634/35), resident...
# 4                                      Self-Portrait
#
#                                             title_nl  principal_maker  \
# 0  Portret Govert van Slingelandt (1623-90), zijn...      Jan Mijtens
# 1  A Shepherdess, known as ‘The beautiful Shepher...  Paulus Moreelse
# 2  Portret van een man, mogelijk Reijnier Pauw (1...  Paulus Moreelse
# ...

# %%
#filter for the words 'interior' or 'interieur' in the dataframe
filtered_data = dataunfiltered[dataunfiltered['description'].str.contains('interieur|interior|room|voorhuis|kamer|kitchen|keuken', na=False) |
                             dataunfiltered['title_nl'].str.contains('interieur|interior|room|voorhuis|kamer|kitchen|keuken', na=False) |
                             dataunfiltered['title_en'].str.contains('interieur|interior|room|voorhuis|kamer|kitchen|keuken', na=False)]
filtered_data.head()
# Out:
#                                      id objectNumber  \
# 9   https://id.rijksmuseum.nl/200107821     SK-C-200
# 14  https://id.rijksmuseum.nl/200107873     SK-A-834
# 20  https://id.rijksmuseum.nl/200107929       SK-C-6
# 50  https://id.rijksmuseum.nl/200108176    SK-A-2539
# 89  https://id.rijksmuseum.nl/200108407    SK-A-4055
#
#                                              title_en  \
# 9                        Boerengezelschap binnenshuis
# 14                      Watermill by a Wooded Outcrop
# 20  De Staalmeesters: het college van staalmeester...
# 50  The Man-of-War Brielle on the River Maas off R...
# 89  Interior of a Protestant, Gothic Church during...
#
#                                              title_nl principal_maker  \
# 9                             Peasants in an Interior               —
# 14                  Watermolen bij een beboste heuvel               —
# 20  De waardijns van het Amsterdamse lakenbereider...               —
# ...

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 9 to 740
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     37 non-null     object
#  1   objectNumber           37 non-null     object
#  2   title_en               37 non-null     object
#  3   title_nl               37 non-null     object
#  4   principal_maker        37 non-null     object
#  5   date_begin             37 non-null     object
#  6   date_end               37 non-null     object
#  7   description            37 non-null     object
#  8   materials              37 non-null     object
#  9   techniques             37 non-null     object
#  10  direct_image_urls      37 non-null     object
#  11  derived_image_url      37 non-null     object
#  12  height_cm              37 non-null     object
#  13  width_cm               37 non-null     object
# ...
